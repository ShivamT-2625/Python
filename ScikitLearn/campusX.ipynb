# %%
import pandas as pd
import numpy as np
import sklearn as sklearn

# %%
df = pd.read_csv("./hiring.csv")
df

import requests
from io import StringIO
url ="https://raw.githubusercontent.com/nytimes/covid-19-data/master/live/us-counties.csv"
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/237.84.2.178 Safari/537.36"}
req = requests.get(url,headers=headers)
data = StringIO(req.text)
fd = pd.read_csv(data)
fd
# Out:
#             date             county         state     fips  cases  deaths
# 0     2023-03-24          McPherson  South Dakota  46089.0    534    16.0
# 1     2023-03-24              Meade  South Dakota  46093.0   8404    68.0
# 2     2023-03-24           Mellette  South Dakota  46095.0    654     8.0
# 3     2023-03-24              Miner  South Dakota  46097.0    542    15.0
# 4     2023-03-24           Jennings       Indiana  18079.0   8178   119.0
# ...          ...                ...           ...      ...    ...     ...
# 3252  2023-03-24  Newport News city      Virginia  51700.0  49995   459.0
# 3253  2023-03-24       Norfolk city      Virginia  51710.0  54167   549.0
# 3254  2023-03-24        Northampton      Virginia  51131.0   2914    78.0
# 3255  2023-03-24     Northumberland      Virginia  51133.0   2719    47.0
# 3256  2023-03-24        Norton city      Virginia  51720.0   1620    22.0
#
# [3257 rows x 6 columns]

# %%
pf = pd.read_csv("./dataset.selected.tsv",sep="\t")
pf
#this was for reading the tsv files using pd.read_csv " generally that sep is default set to "," but for tsv it is "\t"
#for names of the columns names=[e1,e2,e3,e4,e5,e6]
# Out:
#     en         original                                                  ?  \
# 0   en         original                                                  ?
# 1   fr         original  I am sure this monument is in my guide, it is ...
# 2   fr         original  I am sure this monument is in my guide, it is ...
# 3   jp             test  The professor gave the student a bad grade bec...
# 4   jp             test  The professor gave the student a bad grade bec...
# 5   ru  superglue.train             The pike ate the roach. It was hungry.
# 6   ru  superglue.train          The pike ate the roach. It was delicious.
# 7   zh         original  Wang Yan stood behind Li Mei and could not see...
# 8   zh         original  Wang Yan stood behind Li Mei and could not see...
# 9   pt         original  I removed the water bottle from the backpack s...
# 10  pt         original  I removed the water bottle from the backpack s...
#
#    Bob paid for Charlie's college education. He is very generous.  \
# ...

# %%
fg = pd.read_json("./test.json/test.json")
fg
#Working with JSON
# Out:
#          id                                        ingredients
# 0     18009  [baking powder, eggs, all-purpose flour, raisi...
# 1     28583  [sugar, egg yolks, corn starch, cream of tarta...
# 2     41580  [sausage links, fennel bulb, fronds, olive oil...
# 3     29752  [meat cuts, file powder, smoked sausage, okra,...
# 4     35687  [ground black pepper, salt, sausage casings, l...
# ...     ...                                                ...
# 9939  30246  [large egg yolks, fresh lemon juice, sugar, bo...
# 9940  36028  [hot sauce, butter, sweet potatoes, adobo sauc...
# 9941  22339  [black pepper, salt, parmigiano reggiano chees...
# 9942  42525  [cheddar cheese, cayenne, paprika, plum tomato...
# 9943   1443  [cold water, olive oil, lime wedges, garlic cl...
#
# [9944 rows x 2 columns]

# %% [markdown]
# ## Understanding the DATA

# %%
import pandas as pd
data = pd.read_csv("insurance_data.csv")
data.shape
# Out:
# (27, 2)

# %%
data.head(4)
#instead use sample(gives out random values)
data.sample(5)
# Out:
#     age  bought_insurance
# 18   19                 0
# 9    61                 1
# 8    62                 1
# 3    52                 0
# 13   29                 0

# %%
data.info()
data.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               27 non-null     int64
#  1   bought_insurance  27 non-null     int64
# dtypes: int64(2)
# memory usage: 564.0 bytes
# age                 0
# bought_insurance    0
# dtype: int64

# %%
df.describe()
#gives out mathematical parameters from the datasets
# Out:
#        test_score(out of 10)  interview_score(out of 10)    salary($)
# count               7.000000                    8.000000      8.00000
# mean                7.857143                    7.875000  63000.00000
# std                 1.345185                    1.642081  11501.55269
# min                 6.000000                    6.000000  45000.00000
# 25%                 7.000000                    6.750000  57500.00000
# 50%                 8.000000                    7.500000  63500.00000
# 75%                 8.500000                    9.250000  70500.00000
# max                10.000000                   10.000000  80000.00000

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
#correlation between cols
df.corr()["AnyColumn"]
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   experience                  6 non-null      str
#  1   test_score(out of 10)       7 non-null      float64
#  2   interview_score(out of 10)  8 non-null      int64
#  3   salary($)                   8 non-null      int64
# dtypes: float64(1), int64(2), str(1)
# memory usage: 388.0 bytes

# %% [markdown]
# # Univariate Analysis

# %%
import pandas as pd 
tt = pd.read_csv("Titanic-Dataset.csv")
tt.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#for Categorical Data

tt["Survived"].value_counts().plot(kind="pie",autopct="%1.1f%%")
sns.countplot(x =tt["Pclass"])
# Out:
# c:\Users\shiva\OneDrive\Desktop\CODE\AIML\.venv\Lib\site-packages\seaborn\categorical.py:379: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(-.5, n - .5, auto=None)
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
#Numerical Data understanding the distribution
plt.hist(tt["Age"])
#this hist plot tells about the number of people in mid age has more count
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(tt["Age"])
#distplot talks about the skewnesss of the data it also tells about the probability of the numbers 
#there is function df["parameter"].skew()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_13284\1165423815.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tt["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# sns.boxplot(tt["Age"])
#These boxplots helps understand the outliers present in the data along with the noise in the dataset and helps in cleaning the data
sns.boxplot(x=tt["Fare"])
# Out:
# <Axes: xlabel='Fare'>
