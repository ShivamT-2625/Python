# %% [markdown]
# ### Starting with the logistic regression

# %% [markdown]
# ### perceptron :- we draw line by moving it from start towards the convergence(where all the classification is correct)

# %% [markdown]
# #### AX+BY+C = 0
# #### when change C it draws a parallel line to the original line
# #### when change A it changes the point on Y axis and the change in B changes the point on X axis .

# %% [markdown]
# ### If a negative point is in positive region then we subtract its coordinate with the line equation and this yields us a line which transforms it into negative we add positive point in negative region its coordinate with the line equation when we have

# %% [markdown]
# ### we usually do this changes using learning co-efficient subtraction from the equation to avoid changing the transformation abruptly.

# %% [markdown]
# # Algorithm
# ### we define the Wo+W1X1+W2X2=0 , we put the values init and get the prediction . If the overall answer is < 0 then its prediction will be NO PLACEMENT or failed in placement , and > 0 will yield yes predicted

# %% [markdown]
# ## Online Learning
# #### In online learning , we train model on the upcoming data online on the server directly using methods like partial fit(SDG regression) and sometimes using dedicated libraries like River
# #### Learning rate :- rate at which the model is being trained , Out of Core learning is where huge data which cant be loaded directly on the system so it is divided into chunks and trained online .

# %% [markdown]
# ### issues with the Online learning
# ##### Tricky to use & Risky (spammed data and all )

# %% [markdown]
# ### Instance based learning and model based learning
# #### instance algorithm memorizes the data and the model based learning tries to find out the patterns with in the data

# %% [markdown]
# ### Machine Learning Development LifeCycle

# %% [markdown]
# #### 1. Framing the problem \n 2.Gathering Data (Not so easy) [ETL=> Extract , Transform , Load] \n 3.Data PreProcessing (remove duplicates , remove missing values , Outliers removal , Scaling and Normalize the values) \n 4.EDA (Exploratory Data Analysis) relationship between input and output (Basically experimenting with data and relations) like univariant , bivariant relations \n 5. feature engineering and selection (input columns me changes krna and decide krna best one ) \n 6.Model training and Evaluation , ensemble learning (stacking up multiple model and combine them making a super model) \n 7.Model Deployment (pkl file and it is given to API ) 8 Testing (giving out people to test the model )\n 9.Optimize
