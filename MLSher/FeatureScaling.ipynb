# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv("./Social_Network_Ads.csv")
df.sample(5)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 339  15665760    Male   39           122000          1
# 340  15588080  Female   53           104000          1
# 83   15711218    Male   35            88000          0
# 221  15663161    Male   35            91000          1
# 86   15694946    Male   24            55000          0

# %%
#step 1(IN feature scaling) is to do the train test split 
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df[["Age","EstimatedSalary"]],df["Purchased"],test_size=0.2,random_state=0)

# %% [markdown]
# ## Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train) #It learns the parameters
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test) #transforms the value using formula {X'-Xmean/sd}
#though this transformation returns a numpy array which needs to be transformed into data frame.

# %%
X_train_scaled
# Out:
# array([[ 1.92295008e+00,  2.14601566e+00],
#        [ 2.02016082e+00,  3.78719297e-01],
#        [-1.38221530e+00, -4.32498705e-01],
#        [-1.18779381e+00, -1.01194013e+00],
#        [ 1.92295008e+00, -9.25023920e-01],
#        [ 3.67578135e-01,  2.91803083e-01],
#        [ 1.73156642e-01,  1.46942725e-01],
#        [ 2.02016082e+00,  1.74040666e+00],
#        [ 7.56421121e-01, -8.38107706e-01],
#        [ 2.70367388e-01, -2.87638347e-01],
#        [ 3.67578135e-01, -1.71750061e-01],
#        [-1.18475597e-01,  2.20395980e+00],
#        [-1.47942605e+00, -6.35303205e-01],
#        [-1.28500455e+00, -1.06988428e+00],
#        [-1.38221530e+00,  4.07691369e-01],
#        [-1.09058306e+00,  7.55356227e-01],
#        [-1.47942605e+00, -2.00722133e-01],
#        [ 9.50842613e-01, -1.06988428e+00],
#        [ 9.50842613e-01,  5.81523798e-01],
#        [ 3.67578135e-01,  9.87132798e-01],
#        [ 5.61999628e-01, -8.96051849e-01],
#        [-6.04529329e-01,  1.45068594e+00],
# ...

# %%
X_train_scaled = pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
X_train_scaled
# Out:
#           Age  EstimatedSalary
# 0    1.922950         2.146016
# 1    2.020161         0.378719
# 2   -1.382215        -0.432499
# 3   -1.187794        -1.011940
# 4    1.922950        -0.925024
# ..        ...              ...
# 315  0.950843        -1.156800
# 316 -0.896162        -0.780164
# 317 -0.215686        -0.519415
# 318 -1.090583        -0.461471
# 319 -1.187794         1.392742
#
# [320 rows x 2 columns]

# %%
 np.round(X_train.describe())
# Out:
#          Age  EstimatedSalary
# count  320.0            320.0
# mean    38.0          69928.0
# std     10.0          34570.0
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     38.0          69500.0
# 75%     46.0          88000.0
# max     60.0         150000.0

# %%
np.round(X_train_scaled.describe())
# Out:
#          Age  EstimatedSalary
# count  320.0            320.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -2.0             -2.0
# 25%     -1.0             -1.0
# 50%     -0.0             -0.0
# 75%      1.0              1.0
# max      2.0              2.0

# %% [markdown]
# ## Results

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,5))

#before scaling the values
ax1.set_title("Before Scaling")
sns.kdeplot(X_train["Age"],ax=ax1)
sns.kdeplot(X_train["EstimatedSalary"],ax=ax1)

#after it scaled
ax2.set_title("After scaling")
sns.kdeplot(X_train_scaled["Age"],ax=ax2)
sns.kdeplot(X_train_scaled["EstimatedSalary"],ax=ax2)
plt.show()

# %% [markdown]
# ## Originally the distribution shape of the columns remains same though the mean becomes 0 and SD becomes 1

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model_scaled = LogisticRegression()
model.fit(X_train,y_train)
model_scaled.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
y_pred_scaled = model_scaled.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score
print("Accuracy without scaling:",accuracy_score(y_test,y_pred))
print("Accuracy with scaling:",accuracy_score(y_test,y_pred_scaled))
# Out:
# Accuracy without scaling: 0.9125
# Accuracy with scaling: 0.925

# %% [markdown]
# # Effects of Outliers

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
new_rows = pd.DataFrame({
    'Age':[5,90,95],
    'EstimatedSalary':[1000,250000,350000],
    'Purchased':[0,1,1]
})

df = pd.concat([df, new_rows], ignore_index=True)

# %%
plt.scatter(df['Age'], df['EstimatedSalary'])

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train,y_test = train_test_split(df[["Age","EstimatedSalary"]],df["Purchased"],test_size=0.2,random_state=0)

from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
scaler.fit(X_train)
X_train_scaled_out = scaler.transform(X_train)
X_test_scaled_out = scaler.transform(X_test)

# %%
X_train_scaled_out = pd.DataFrame(X_train_scaled_out,columns=X_train.columns)
X_test_scaled_out = pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
np.round(X_train_scaled_out.describe())
# Out:
#          Age  EstimatedSalary
# count  322.0            322.0
# mean    -0.0             -0.0
# std      1.0              1.0
# min     -3.0             -2.0
# 25%     -1.0             -1.0
# 50%     -0.0              0.0
# 75%      1.0              1.0
# max      5.0              5.0

# %%
np.round(X_train.describe())
# Out:
#          Age  EstimatedSalary
# count  322.0            322.0
# mean    38.0          69724.0
# std     11.0          35250.0
# min      5.0           1000.0
# 25%     30.0          43000.0
# 50%     38.0          70000.0
# 75%     46.0          88000.0
# max     90.0         250000.0

# %%
from sklearn.linear_model import LogisticRegression
model_out = LogisticRegression()
model_scaled_out = LogisticRegression()

model_out.fit(X_train,y_train)
model_scaled_out.fit(X_train_scaled_out,y_train)
# Out:
# LogisticRegression()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(X_train['Age'], X_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled_out['Age'], X_train_scaled_out['EstimatedSalary'],color='red')
ax2.set_title("After Scaling")
plt.show()

# %% [markdown]
# # The Outliers are not affected by feature scaling they needs to be treated independently

# %% [markdown]
# ### When to use Standardization :-
# ### k-means , KNN,PCA , Artificial Neural Network , Gradient Descent.
